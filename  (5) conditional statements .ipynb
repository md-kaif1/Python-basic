# %%
a=4
if(a>5):
  print("true")
else:
  print("False")
# Out:
# False

# %%
a=int(input("enter the numder:"))
if(a>10):
  print("a is greater")
elif (a<10):
  print("a is less")
elif (a>=10000):
  print("Huge")
# Out:
# enter the numder:10000
# a is greater

# %%
x=4
y=6
if x>3:
  if (y>2):
    print("both greater")
  else:
      print("xis greater and y is small")
else:
  print("x is not greater then 6")
# Out:
# both greater
