# %%
a=4
a #the memory block is created with referance namea and value 4
# Out:
# 4

# %%
b="kaif"
b
# Out:
# 'kaif'

# %%
b[0]
# Out:
# 'k'

# %%
b[-4]
# Out:
# 'k'

# %% [markdown]
# Another type of date container

# %%
list_cont=[1,2,3,4,3+5j,"true","kaif"]
list_cont[0]
# Out:
# 4

# %%
list_cont[4]
# Out:
# (3+5j)

# %%
list_cont[-1]
# Out:
# 'kaif'

# %% [markdown]
# Main concept of mutability(change) and immutability

# %%
list_cont[6]
# Out:
# 'kaif'

# %%
list_cont[6]="Roshan"
list_cont
# Out:
# [1, 2, 3, 4, (3+5j), 'true', 'Roshan']

# %% [markdown]
# -> object /container whose state or  value can be change after they are created are called as muatibility object/container ,also called as item assignment.
# ->list is the type of mutble object/support item assignment.

# %%
b="pwskills"
b
# Out:
# 'pwskills'

# %%
b[0]=M
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-21-3651594470.py in <cell line: 0>()
# ----> 1 b[0]=M
#
# NameError: name 'M' is not defined

# %% [markdown]
# ->STRING OBJECT DOESNOT SUPPORT ITEM ASSIGMENT CALLED AS IMMUTABLE OBJECT

# %% [markdown]
# *LIST IS CALLED AS MUTABLE OBJECT AND STRING IS CALLED AS IMMUTABLE OBJECT.
