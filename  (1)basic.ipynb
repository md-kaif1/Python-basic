# %%
print("Helo!!")
# Out:
# Helo!!

# %%
a=5
a
# Out:
# 5

# %%
c="AJYA"
c
# Out:
# 'AJYA'

# %%
b=5.2
type(b)
# Out:
# float

# %%
com=4+6j
type(com)
# Out:
# complex

# %% [markdown]
# valid varible should be contineous

# %%
data_science= "pwskills"
data_science
# Out:
# 'pwskills'

# %%
#This is a single line comment
#using bool data type
a=True
b=False
type(a)
# Out:
# bool

# %%
#This is a multi line comment
'''
Multiline comment
I am student
'''
a=5
a
# Out:
# 5

# %%
#what is type and print?
#>key word and pre define words

# %%
help('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
#indentation>>more readable
if 3>2:
  print("greater")
# Out:
# greater

# %%
#Assignment statement
d=7
d
# Out:
# 7

# %%
#Expression statement
a=2 #assigment
b=3 #assigment
a+b #Expression
# Out:
# 5

# %%
#input output
name = input("please enter your name:")
# Out:
# please enter your name:kaif

# %%
#input output
name = input("please enter your name:")
# Out:
# please enter your name:2

# %%
#here input treat all value as a string so to change this data tyoe we have todo type casting
name
# Out:
# '2'

# %%
type(name)
# Out:
# str

# %%
name=int(name)
name
# Out:
# 2

# %%
type(name)
# Out:
# int

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %% [markdown]
# key word should not be varible

# %% [markdown]
# important points
# 1.input always return string no      matter what data type.use typecasting.
# 2. key word should not be varible
