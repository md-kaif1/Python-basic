# %%
a=4
b=5
a+b
# Out:
# 9

# %%
a="4"
b=3
a+b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2-2759264426.py in <cell line: 0>()
#       1 a="4"
#       2 b=3
# ----> 3 a+b
#
# TypeError: can only concatenate str (not "int") to str

# %%
type(a)
# Out:
# str

# %% [markdown]
# now type casting

# %%
a="4"
b=5
int(a)+b
# Out:
# 9

# %%
a="9"
print(type(a))
print(type(int(a)))
# Out:
# <class 'str'>
# <class 'int'>

# %%
a="Mdkaif" #string cannot be typecast.
type(a)
# Out:
# str

# %%
int(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-7-766485689.py in <cell line: 0>()
# ----> 1 int(a)
#
# ValueError: invalid literal for int() with base 10: 'Mdkaif'

# %%
#integer to string
a=5
type(a)
# Out:
# int

# %%
a
# Out:
# 5

# %%
b=str(a)
b
# Out:
# '5'

# %% [markdown]
# ->typecasting>> implicit and explicit

# %%
#implecit
a=5
a
# Out:
# 5

# %%
a=3
b=3.9
a+b
# Out:
# 6.9

# %%
#explecit
a="ajay"
b=5
a+b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-13-3479600489.py in <cell line: 0>()
#       2 a="ajay"
#       3 b=5
# ----> 4 a+b
#
# TypeError: can only concatenate str (not "int") to str

# %%
a="ajay"
b="mohan"
a+b #also known as concatination
# Out:
# 'ajaymohan'

# %%
"john"+" 100"
# Out:
# 'john 100'
