# %%
a=int(input("enter the range:"))
for i in range(a):
  for j in range(a):
    print("*", end=" ")
  print()
# Out:
# enter the range:5
# * * * * *
# * * * * *
# * * * * *
# * * * * *
# * * * * *

# %%
for i in range(5):
  for j in range(i):
    print("*", end=" ")
  print()
# Out:
# * *
#
# * * * *

# %%
numbers={1,2,3,4,5}
print(numbers)
# Out:
# {1, 2, 3, 4, 5}

# %%
num_list = [1, 2, 3, 4, 5]
print(len(num_list))
# Out:
# 5

# %%
for i in range(3,0,-1):
  print(i)
# Out:
# 3
# 2
# 1
